# %% [markdown]
# # Adım 1: Docker Ortamının Kurulumu
#
# Bu projede, tüm bileşenlerin izole ve tekrarlanabilir bir ortamda çalışması için **Docker** ve **Docker Compose** kullanılmıştır. Bu notebook, sistem mimarisini ve servislerin kurulum adımlarını açıklar.

# %% [markdown]
# ## 1.1. Servis Mimarisi
#
# Proje aşağıdaki servislerden oluşmaktadır:
#
# 1.  **Zookeeper:** Kafka'nın koordinasyonunu sağlar.
# 2.  **Kafka Broker:** Streaming veri akışı için mesaj kuyruğu sistemidir.
# 3.  **Python Producer:** CSV dosyasından veri okuyup Kafka'ya JSON formatında gönderen özel uygulamadır.
# 4.  **Apache Spark (Master & Worker):** Dağıtık veri işleme motorudur.
# 5.  **Spark Processor:** Spark Structured Streaming işlerini koşturan ana konteyner.
# 6.  **MLflow:** Model eğitim süreçlerini ve metrikleri takip eden sunucu.

# %% [markdown]
# ## 1.2. Docker Compose Yapılandırması
#
# Aşağıdaki hücrede projenin `docker-compose.yml` dosyasının içeriği gösterilmektedir.

# %%
with open('../docker-compose.yml', 'r') as f:
    print(f.read())

# %% [markdown]
# ## 1.3. Servislerin Başlatılması
#
# Tüm servisleri ayağa kaldırmak için terminalde şu komut kullanılır:
#
# ```bash
# docker-compose up -d --build
# ```
#
# ### Servis Durum Kontrolü
#
# Servislerin başarıyla ayağa kalktığını doğrulamak için `docker ps` komutu ile konteyner listesi kontrol edilmelidir.

# %% [markdown]
# ## 1.4. Ekran Görüntüleri
#
# > **Not:** Bu bölüme Docker Desktop veya terminal çıktısının ekran görüntüleri eklenmelidir.
#
# ![Docker Servisleri](../logs/docker_status_placeholder.png)
