# %% [markdown]
# # Adım 4: Keşifsel Veri Analizi (EDA)
#
# Delta Lake (Silver Katmanı) üzerinde biriken veriler kullanılarak kapsamlı bir keşifsel veri analizi gerçekleştirilmiştir. Bu analiz, verinin kalitesini anlamak ve modelleme öncesi trendleri belirlemek için kritik öneme sahiptir.

# %% [markdown]
# ## 4.1. Analiz Başlıkları
#
# Analiz süreci şu temel metrikleri kapsamaktadır:
# - **Temel İstatistikler:** Toplam satır sayısı, benzersiz kullanıcı ve olay sayıları.
# - **Eksik Değer Analizi:** Veri setindeki null değerlerin tespiti ve görselleştirilmesi.
# - **Zaman Serisi Analizi:** Saatlik ve günlük olay trafikleri.
# - **Dağılım Analizi:** Olay tiplerinin ve kullanıcı aktivitelerinin dağılımı.

# %% [markdown]
# ## 4.2. EDA Kaynak Kodu
#
# Aşağıdaki hücrede `spark/eda_analysis.py` dosyasının içeriği gösterilmektedir.

# %%
with open('../spark/eda_analysis.py', 'r') as f:
    print(f.read())

# %% [markdown]
# ## 4.3. Görselleştirme Bulguları
#
# Aşağıda analiz sonucunda üretilen temel grafikler yer almaktadır:
#
# 1.  **Eksik Değerler:**
#     ![Missing Values](../data/plots/01_missing_values.png)
# 2.  **Saatlik Trend:**
#     ![Hourly Trend](../data/plots/02_hourly_trend.png)
# 3.  **Olay Dağılımı:**
#     ![Event Distribution](../data/plots/04_event_pie_chart.png)
# 4.  **Kullanıcı Aktivitesi:**
#     ![User Activity](../data/plots/05_user_activity_dist.png)
