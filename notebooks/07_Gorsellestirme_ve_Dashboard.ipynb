# %% [markdown]
# # Adım 7: Görselleştirme ve Dashboard
#
# Projenin son aşamasında, elde edilen tüm sonuçlar interaktif bir dashboard üzerinden sunulmuştur. Bu dashboard, hem veri mühendisliği (EDA) hem de veri bilimi (ML) süreçlerinin çıktılarını tek bir merkezden izlemeye olanak tanır.

# %% [markdown]
# ## 7.1. Dashboard Teknolojisi ve Tasarımı
#
# - **Teknoloji:** Python tabanlı **Streamlit** kütüphanesi kullanılmıştır.
# - **Görselleştirme:** Plotly, Matplotlib ve Seaborn grafik kütüphaneleri entegre edilmiştir.
# - **Estetik:** Modern web tasarım prensiplerine uygun, koyu tema ve premium bir arayüz geliştirilmiştir.

# %% [markdown]
# ## 7.2. Zorunlu Görseller ve Dashboard İçeriği
#
# Dashboard şu ana bileşenleri içermektedir:
# 1.  **Model Karşılaştırma:** 5 modelin performansını gösteren interaktif grafikler.
# 2.  **Feature Importance:** Modellerin karar mekanizmalarını açıklayan grafikler.
# 3.  **Zaman Serisi Trendleri:** Verideki trafik akışı.
# 4.  **Residual Analizi:** Modellerin hata dağılımları.
# 5.  **EDA Özetleri:** Veri dağılımı ve eksik değer analizleri.

# %% [markdown]
# ## 7.3. Dashboard Uygulama Kodu
#
# Aşağıdaki hücrede `dashboard/app.py` dosyasının içeriği gösterilmektedir.

# %%
with open('../dashboard/app.py', 'r') as f:
    print(f.read())

# %% [markdown]
# ## 7.4. Dashboard Görünümü
#
# Çalışan uygulamadan alınan örnek ekran görüntüleri:
#
# ![Dashboard Overview](../dashboard/dashboard_screenshot_placeholder.png)
