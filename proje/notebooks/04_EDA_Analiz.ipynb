# %% [markdown]
# # Adım 4: Keşifsel Veri Analizi (EDA)
#
# Delta Lake tablolarına (Silver Katmanı) yazılan veriler üzerinde gerçekleştirilen kapsamlı analiz sonuçları aşağıda özetlenmiştir.

# %% [markdown]
# ## 4.1. Analiz Bulguları
#
# ### Genel İstatistikler
# ![General Stats](../data/plots/00_general_stats.png)
#
# ### Eksik Değerler
# ![Missing Values](../data/plots/01_missing_values.png)
#
# ### Zaman Serisi Trendleri
# ![Hourly Trend](../data/plots/02_hourly_trend.png)
# ![Daily Trend](../data/plots/03_daily_trend.png)
#
# ### Dağılım Analizleri
# ![Country Distribution](../data/plots/04_event_pie_chart.png)
# ![Quantity Distribution](../data/plots/05_user_activity_dist.png)

# %%
# EDA Analiz Kodunu Görüntüle
with open('../spark/eda_analysis.py', 'r') as f:
    print(f.read())
